# %% [markdown]
# References:
#
#     https://www.projectpro.io/article/bert-nlp-model-explained/558
#     https://mccormickml.com/2019/05/14/BERT-word-embeddings-tutorial/
#     https://huggingface.co/docs/transformers/main_classes/tokenizer
#     https://medium.com/@khang.pham.exxact/text-classification-with-bert-7afaacc5e49b

# %% [markdown]
# 1) [1p]
# Install the transformers module.
# Obtain the senseval instances for a word of your choice (by usingthe instances() method)
# Create a DataFrame, called <i>df</i>, based on the sentences in the text with the columns: text, label, id. Each row will correspond to an entry in the corpus. The column text would contain the phrase from the entry (as raw text - untagged), the label will be the sense for the target word (the label should be an int), the id is the number of the phrase.

# %%
from nltk.corpus import senseval



#print(df.head())

# %% [markdown]
# 2) [1p]
# <ol>
# <li>Shuffle the data. For the training set, use 90% of instances to train the classifier and try to find the sense of the word on the rest of 10% of instances and compare it to the result. The classes used for training are the senses.
#
# <li>Create a classification model (pretrained) with BertForSequenceClassification.
# The number of labels is actually the number of classes. Set the output attentions an hidden states on false.
#
# <li>In variable <i>tokenizer</i> load BertTokenizer from pretrained model "bert-base-uncased", in lowercase
# Use batch_encode_plus method of the tokenizer to encode the texts, and put the resultin varaible <i>encodings</i>. Use the longest padding and return the attention mask.
#
# <li>For each epoch load a batch and train the model with that batch (this is the step where we do the fine tunning). don't forget to use zero_grad() on the optimizer.
# </ol>

# %%
#TO DO solve the task and uncommenty the last lines for verification



# tokens = tokenizer.convert_ids_to_tokens(encodings)
# print("Tokens:", tokens)

# %% [markdown]
# 3) [1p] Use 2 epochs to train the data using AdamW optimizer with learning rate 5e-5 and with batch sizes of:
# <ul>
#     <li>16
#     <li>32
#     <li>64
# </ul>

# %% [markdown]
# 4) [1p] For each batch size, try training with 2, 3 and 4 epochs. Print the loss both for training and testing. Choose the number of epochs based on the values of the loss function for each batch.
# Justify your choice with a table (columns will correspond to the number of epochs and rows to the loss function values for training and testing).
# Print how much time each training epoch took.

# %%
#TO DO

# %% [markdown]
# 5) [1p] Classify the text based on the model you just created using the test set. You again load in batches the data and check the predictions.
# Print the accuracy, precision, recall, f1-score
# Plot the confusion matrix.

# %%
#TO DO
